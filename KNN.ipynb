# %%
import pandas as pd
import numpy as np

df = pd.read_csv("p3/stats.csv")

df = df.drop('Unnamed: 0', 1)

cols = df.columns.tolist()
cols = cols[-1:] + cols[:-1]
df = df[cols]

df
# Out:
#                     full_name   season    GP   MIN   PTS  FGM   FGA   FG%  \
# 0                Steven Adams  2019-20  55.0  27.0  11.0  4.6   7.8  58.9
# 1                 Bam Adebayo  2019-20  61.0  34.4  16.2  6.2  11.0  56.5
# 2           LaMarcus Aldridge  2019-20  52.0  33.0  18.8  7.3  14.8  49.5
# 3              Kyle Alexander  2019-20   2.0   6.8   0.0  0.0   0.0   0.0
# 4    Nickeil Alexander-Walker  2019-20  41.0  12.2   5.1  1.9   5.5  33.9
# ..                        ...      ...   ...   ...   ...  ...   ...   ...
# 452            Garrett Temple  2019-20  55.0  28.1  10.3  3.6   9.5  37.8
# 453              Daniel Theis  2019-20  54.0  23.6   9.1  3.6   6.6  55.6
# 454             Isaiah Thomas  2019-20  40.0  23.1  12.2  4.4  10.7  40.8
# 455              Khyri Thomas  2019-20   5.0   5.1   1.4  0.4   1.2  33.3
# 456               Matt Thomas  2019-20  30.0   9.9   4.6  1.6   3.3  49.5
#
#      3PM  3PA  ...   REB  AST  TOV  STL  BLK   PF    FP   DD2  TD3  +/-
# ...

# %%
df_train = df.loc[:228].copy()
df_test = df.loc[229:].copy()

# %%
df_train = df_train[df_train.PTS != 0]
df_train = df_train[df_train.MIN != 0]
df_train = df_train[df_train.GP != 0]

df_test = df_test[df_test.PTS != 0]
df_test = df_test[df_test.MIN != 0]
df_test = df_test[df_test.GP != 0]


df_test
#df_train.loc[df['PTS'] == 0]
# Out:
#               full_name   season    GP   MIN   PTS  FGM   FGA   FG%  3PM  3PA  \
# 229       Kevin Huerter  2019-20  52.0  31.0  12.3  4.5  10.8  41.5  2.3  5.9
# 230     De'Andre Hunter  2019-20  59.0  31.9  12.4  4.5  10.9  41.3  1.7  4.8
# 231  Chandler Hutchison  2019-20  28.0  18.8   7.8  2.9   6.3  45.7  0.4  1.4
# 232         Serge Ibaka  2019-20  47.0  27.1  15.9  6.4  12.4  51.8  1.3  3.2
# 233      Andre Iguodala  2019-20  10.0  18.3   4.2  1.7   3.6  47.2  0.7  1.9
# ..                  ...      ...   ...   ...   ...  ...   ...   ...  ...  ...
# 452      Garrett Temple  2019-20  55.0  28.1  10.3  3.6   9.5  37.8  2.0  6.3
# 453        Daniel Theis  2019-20  54.0  23.6   9.1  3.6   6.6  55.6  0.4  1.4
# 454       Isaiah Thomas  2019-20  40.0  23.1  12.2  4.4  10.7  40.8  2.0  4.7
# 455        Khyri Thomas  2019-20   5.0   5.1   1.4  0.4   1.2  33.3  0.4  1.0
# 456         Matt Thomas  2019-20  30.0   9.9   4.6  1.6   3.3  49.5  1.1  2.3
#
# ...

# %%
df_train["log(PTS)"] = np.log(df_train["PTS"])
df_train
# Out:
#                     full_name   season    GP   MIN   PTS  FGM   FGA   FG%  \
# 0                Steven Adams  2019-20  55.0  27.0  11.0  4.6   7.8  58.9
# 1                 Bam Adebayo  2019-20  61.0  34.4  16.2  6.2  11.0  56.5
# 2           LaMarcus Aldridge  2019-20  52.0  33.0  18.8  7.3  14.8  49.5
# 4    Nickeil Alexander-Walker  2019-20  41.0  12.2   5.1  1.9   5.5  33.9
# 5               Grayson Allen  2019-20  30.0  16.6   7.4  2.6   5.9  44.9
# ..                        ...      ...   ...   ...   ...  ...   ...   ...
# 222            Richaun Holmes  2019-20  37.0  29.4  13.1  5.5   8.4  66.0
# 223               Rodney Hood  2019-20  21.0  29.5  11.0  4.1   8.2  50.6
# 224                Al Horford  2019-20  57.0  30.6  11.6  4.6  10.8  43.2
# 226           Danuel HouseJr.  2019-20  54.0  30.5  10.5  3.6   8.5  42.7
# 227             Dwight Howard  2019-20  60.0  19.6   7.8  3.1   4.3  73.7
#
#      3PM  3PA  ...  AST  TOV  STL  BLK   PF    FP   DD2  TD3  +/-  log(PTS)
# ...

# %%
import matplotlib.cm as cm

df_train.plot.scatter(x="MIN", y="GP", c="log(PTS)", cmap=cm.YlOrRd)

# %%
X_train = df_train[["MIN", "GP"]]
y_train = df_train["log(PTS)"]

X_train_mean = X_train.mean()
X_train_sd = X_train.std()
X_train_st = (X_train - X_train_mean) / X_train_sd

# %%
x_new = df_test.loc[230, ["MIN", "GP"]]

x_new_st = (x_new - X_train_mean) /X_train_sd
x_new_st
# Out:
# MIN    1.23165
# GP      1.0521
# dtype: object

# %%
dists = np.sqrt(((X_train_st - x_new_st) ** 2).sum(axis=1))
dists

# %%
i_nearest = dists.sort_values().index[:5]
i_nearest

# %%
y_train.loc[i_nearest].mean()
