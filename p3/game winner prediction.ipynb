# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn
from scipy.stats import poisson,skellam
df = pd.read_csv("finaldata.csv")

df = df.drop('Unnamed: 0.1', 1)
df = df.drop('Unnamed: 0', 1)

cols = df.columns.tolist()
cols = cols[-1:] + cols[:-1]
df = df[cols]
df = df.rename(columns={"team_name": "name"})

df
# Out:
#      +/-  height_feet position                   name          full_name  \
# 0    2.3          7.0        C  Oklahoma City Thunder       Steven Adams
# 1    3.5          6.0      C-F             Miami Heat        Bam Adebayo
# 2   -2.6          6.0        F      San Antonio Spurs  LaMarcus Aldridge
# 3   -2.4          6.0        G      Memphis Grizzlies      Grayson Allen
# 4    0.8          6.0        C          Brooklyn Nets      Jarrett Allen
# ..   ...          ...      ...                    ...                ...
# 310 -3.0          6.0        G          Atlanta Hawks        Jeff Teague
# 311 -0.8          6.0      G-F          Brooklyn Nets     Garrett Temple
# 312  3.3          6.0        F         Boston Celtics       Daniel Theis
# 313 -5.0          5.0        G            LA Clippers      Isaiah Thomas
# 314 -3.2          6.0        G        Detroit Pistons       Khyri Thomas
#
#       season    GP   MIN   PTS  FGM  ...  DREB   REB  AST  TOV  STL  BLK   PF  \
# 0    2019-20  55.0  27.0  11.0  4.6  ...   6.0   9.4  2.5  1.5  0.8  1.1  2.0
# 1    2019-20  61.0  34.4  16.2  6.2  ...   8.0  10.5  5.1  2.8  1.2  1.3  2.5
# 2    2019-20  52.0  33.0  18.8  7.3  ...   5.5   7.5  2.4  1.4  0.6  1.6  2.4
# 3    2019-20  30.0  16.6   7.4  2.6  ...   2.0   2.2  1.4  0.8  0.2  0.0  1.2
# 4    2019-20  60.0  26.0  10.8  4.2  ...   6.5   9.6  1.4  1.1  0.6  1.4  2.3
# ..       ...   ...   ...   ...  ...  ...   ...   ...  ...  ...  ...  ...  ...
# 310  2019-20  55.0  25.2  10.9  3.6  ...   2.0   2.4  5.3  2.1  0.8  0.3  1.8
# 311  2019-20  55.0  28.1  10.3  3.6  ...   2.9   3.5  2.6  1.0  0.8  0.5  1.7
# 312  2019-20  54.0  23.6   9.1  3.6  ...   4.4   6.6  1.6  0.8  0.6  1.3  3.5
# 313  2019-20  40.0  23.1  12.2  4.4  ...   1.4   1.7  3.7  1.9  0.3  0.2  1.9
# 314  2019-20   5.0   5.1   1.4  0.4  ...   0.0   0.0  0.2  0.2  0.2  0.0  0.6
#
#        FP   DD2  TD3
# 0    30.3  20.0  0.0
# 1    41.2  37.0  3.0
# 2    36.7  14.0  0.0
# 3    12.1   0.0  0.0
# 4    29.2  26.0  0.0
# ..    ...   ...  ...
# 310  23.1   3.0  0.0
# 311  21.0   1.0  0.0
# 312  24.4   5.0  0.0
# 313  19.2   1.0  0.0
# 314   2.1   0.0  0.0
#
# [315 rows x 29 columns]

# %%
points = df.loc[df['name'] == "Oklahoma City Thunder", 'PTS'].mean()
points
# Out:
# 10.672727272727274

# %%
new_df = df.groupby('name').mean()
new_df.head(10)
# Out:
#                             +/-  height_feet         GP        MIN        PTS  \
# name
# Atlanta Hawks         -3.036364     6.181818  42.272727  21.427273   8.454545
# Boston Celtics         4.316667     6.000000  51.333333  28.600000  14.266667
# Brooklyn Nets         -0.488235     6.000000  35.882353  20.164706   9.182353
# Charlotte Hornets     -4.033333     6.000000  42.111111  22.555556   9.122222
# Chicago Bulls         -1.666667     6.222222  44.222222  21.922222   9.366667
# Cleveland Cavaliers   -2.887500     6.000000  44.375000  20.887500   9.687500
# Dallas Mavericks       1.800000     6.266667  39.533333  19.146667   9.053333
# Denver Nuggets         1.166667     6.083333  47.833333  23.058333  10.341667
# Detroit Pistons       -1.738462     6.076923  38.538462  21.107692   9.123077
# Golden State Warriors -3.616667     6.166667  30.333333  22.633333   9.766667
#
#                             FGM        FGA        FG%       3PM       3PA  \
# name
# Atlanta Hawks          3.318182   6.845455  46.554545  0.709091  2.200000
# Boston Celtics         5.250000  11.283333  46.233333  1.633333  4.400000
# Brooklyn Nets          3.323529   7.700000  40.847059  1.076471  3.241176
# Charlotte Hornets      3.266667   8.033333  37.922222  1.111111  3.333333
# Chicago Bulls          3.411111   7.611111  45.977778  1.033333  3.055556
# Cleveland Cavaliers    3.625000   7.787500  39.150000  0.875000  2.537500
# Dallas Mavericks       3.286667   7.053333  46.393333  1.093333  2.993333
# Denver Nuggets         3.891667   8.333333  46.308333  1.008333  2.858333
# Detroit Pistons        3.246154   7.569231  42.684615  1.215385  3.361538
# Golden State Warriors  3.516667   8.300000  42.016667  0.950000  3.483333
#
#                        ...      DREB       REB       AST       TOV       STL  \
# name                   ...
# Atlanta Hawks          ...  3.590909  4.936364  1.636364  1.181818  0.672727
# Boston Celtics         ...  4.300000  5.366667  2.716667  1.483333  0.950000
# Brooklyn Nets          ...  3.011765  3.852941  1.970588  1.211765  0.594118
# Charlotte Hornets      ...  2.766667  3.711111  2.433333  1.400000  0.688889
# Chicago Bulls          ...  2.800000  3.722222  2.188889  1.300000  0.933333
# Cleveland Cavaliers    ...  3.625000  4.662500  1.900000  1.512500  0.700000
# Dallas Mavericks       ...  3.153333  4.120000  1.893333  1.040000  0.480000
# Denver Nuggets         ...  3.075000  4.075000  2.458333  1.141667  0.741667
# Detroit Pistons        ...  2.076923  2.607692  2.530769  1.223077  0.561538
# Golden State Warriors  ...  3.900000  4.950000  3.283333  1.783333  0.883333
#
#                             BLK        PF         FP       DD2       TD3
# name
# Atlanta Hawks          0.718182  2.227273  19.900000  5.090909  0.000000
# Boston Celtics         0.583333  2.350000  27.966667  5.000000  0.000000
# Brooklyn Nets          0.364706  1.758824  18.423529  3.411765  0.058824
# Charlotte Hornets      0.344444  1.600000  18.922222  3.666667  0.000000
# Chicago Bulls          0.322222  1.877778  19.577778  1.000000  0.000000
# Cleveland Cavaliers    0.325000  1.700000  19.737500  8.750000  0.000000
# Dallas Mavericks       0.473333  1.746667  18.600000  4.533333  0.866667
# Denver Nuggets         0.475000  1.891667  21.366667  4.500000  1.000000
# Detroit Pistons        0.330769  1.646154  17.507692  1.000000  0.000000
# Golden State Warriors  0.583333  2.300000  23.200000  3.000000  0.333333
#
# [10 rows x 25 columns]

# %%
    match = pd.DataFrame(columns=['PTS1','3PM1','REB1','STL1','PTS2','3PM2','REB2','STL2'], index=[0])
    from sklearn.linear_model import LinearRegression

   
    model = LinearRegression()
    team1 = "Denver Nuggets"
    team2 = "Boston Celtics"
    match['PTS1'] = df.loc[df['name'] == team1, 'PTS'].mean()
    match['3PM1'] = df.loc[df['name'] == team1, '3PM'].mean()
    match['REB1'] = df.loc[df['name'] == team1, 'REB'].mean()
    match['STL1'] = df.loc[df['name'] == team1, 'STL'].mean()
    match['AST1'] = df.loc[df['name'] == team1, 'AST'].mean()

    match['PTS2'] = df.loc[df['name'] == team2, 'PTS'].mean()
    match['3PM2'] = df.loc[df['name'] == team2, '3PM'].mean()
    match['REB2'] = df.loc[df['name'] == team2, 'REB'].mean()
    match['STL2'] = df.loc[df['name'] == team2, 'STL'].mean()
    match['AST2'] = df.loc[df['name'] == team2, 'AST'].mean()

    
    match['PTS'] = match['PTS1'] - match['PTS2']
    match['3PM'] = match['3PM1'] - match['3PM2']
    match['REB'] = match['REB1'] - match['REB2']
    match['STL'] = match['STL1'] - match['STL2']
    match['AST'] = match['AST1'] - match['AST2']

    
    match = match[['PTS', '3PM', 'REB', 'STL']]
    

    
    X_train = match[["3PM", 'REB', 'STL']]
    y_train = match["PTS"]
    model = LinearRegression()
    model.fit(X=X_train, y=y_train)
    match_array = match.values
    prediction = model.predict(X=X_train)
    if prediction > 0:
        print("winner is "+ team1)
    elif prediction < 0:
        print("winner is "+team2)
# Out:
# winner is Boston Celtics
